# %% [markdown]
# Julia Joveneau - 42611800
#
# LMAPR1492
#
# March 8, 2021

# %%
from pymatgen.ext.matproj import MPRester
from jupyter_jsmol.pymatgen import quick_view
from pymatgen.io.cif import CifWriter
from pymatgen.io.cif import CifParser
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer

from jupyter_jsmol import JsmolView
from IPython.display import display

from pymatgen import Structure
from jupyter_jsmol.pymatgen import quick_view

# %%
with MPRester("0xKCQrLrxyfoPKG3N") as m:
    structure = m.get_structure_by_material_id("mp-7477")

# %%
view = JsmolView()
display(view)
view.load("RbErO2_mp-7477_symmetrized.cif", '{1 1 1}')

#to uncomment
#view.script("draw symop 2 {atomno=6}")
#view.script("draw symop 13 {atomno=3}")
#view.script("draw symop 7 {atomno=10}")
# Out:
# JsmolView(layout=Layout(align_self='stretch', height='400px'))

# %% [markdown]
# ## 1 : "-x, -y, -z"

# %% [markdown]
# - Inversion avec comme centre de symétrie l'atome #1 en (0,0,0)
# - Envoie l'atome #6 sur l'atome #11
#
# - Opérateur :
# $
# \begin{pmatrix}
# -1 & 0 & 0 \\
# 0 & -1 & 0 \\
# 0 & 0 & -1 \\
# \end{pmatrix}
# $
#
# ![_-x,-y,-z_.png](attachment:_-x,-y,-z_.png)

# %% [markdown]
# ## 2 : "x+2/3, y+1/3, z+1/3"

# %% [markdown]
# - Translation de vecteur (2/3, 1/3, 1/3)
# - Envoie l'atome #3 sur l'atome #8
# - Opérateur : identité suivi de l'addition du vecteur (2/3, 1/3, 1/3)
# ![x+033,y+033,z+033.png](attachment:x+033,y+033,z+033.png)

# %% [markdown]
# ## 3 : "y, x, -z"

# %% [markdown]
# - Rotation d'ordre 2 (180°)
# - Envoie l'atome #10 sur l'atome #13
# - Opérateur :
# $
# \begin{pmatrix}
# 0 & 1 & 0 \\
# 1 & 0 & 0 \\
# 0 & 0 & -1 \\
# \end{pmatrix}
# $
# ![symop7.png](attachment:symop7.png)
